# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('test.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df = pd.get_dummies(df, columns=['gender',	'race/ethnicity',
                            'parental level of education',
                            'lunch', 'test preparation course'], drop_first=True).astype(int)

# %%
df
# Out:
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = df.drop(columns=('math score'))
scaled_data = scaler.fit_transform(features)

# %%
scaled_data
# Out:
# array([[ 0.19399858,  0.39149181, -0.96462528, ..., -0.4669334 ,
#          0.74188112,  0.74674788],
#        [ 1.42747598,  1.31326868, -0.96462528, ..., -0.4669334 ,
#          0.74188112, -1.33914006],
#        [ 1.77010859,  1.64247471, -0.96462528, ..., -0.4669334 ,
#          0.74188112,  0.74674788],
#        ...,
#        [ 0.12547206, -0.20107904, -0.96462528, ..., -0.4669334 ,
#         -1.34792485, -1.33914006],
#        [ 0.60515772,  0.58901542, -0.96462528, ..., -0.4669334 ,
#          0.74188112, -1.33914006],
#        [ 1.15336989,  1.18158627, -0.96462528, ..., -0.4669334 ,
#         -1.34792485,  0.74674788]])

# %%
x = scaled_data
y = df['math score']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lin_model = LinearRegression()

# %%
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_model.predict(x_test)

# %%
y_pred
# Out:
# array([76.3879697 , 58.88597004, 76.99026483, 76.85180448, 87.62737816,
#        79.0140238 , 64.65460865, 53.00791885, 74.18471015, 49.21353815,
#        52.94765047, 36.66906418, 67.9139255 , 52.27725558, 86.71848338,
#        70.53070205, 51.95556639, 46.8314386 , 48.82375101, 52.72669531,
#        73.88582984, 38.88612362, 57.38074421, 36.32839723, 78.14908978,
#        81.79995075, 75.3849409 , 46.1184787 , 31.03596334, 49.90094972,
#        65.98409138, 70.4116652 , 60.5061564 , 83.73986218, 84.43184961,
#        46.07265627, 76.10135181, 70.20596817, 65.85782103,  3.76186106,
#        78.49792748, 67.25291552, 67.97175998, 60.2734092 , 79.67385074,
#        67.60005539, 72.24589185, 24.76000748, 85.95581153, 70.08842684,
#        75.41268803, 66.79864565, 81.16502181, 45.6635254 , 66.11051928,
#        67.32545668, 86.13600492, 58.72739768, 82.23614367, 81.21768838,
#        47.23421792, 72.04512129, 70.64302698, 55.92646405, 86.31798368,
# ...

# %%
from sklearn.metrics import r2_score, accuracy_score, precision_score, f1_score, roc_auc_score, log_loss, confusion_matrix
r2_score(y_test, y_pred)
# Out:
# 0.8804332983749565

# %%
import joblib

joblib.dump(lin_model, 'modelr.pkl')
joblib.dump(scaler, 'scalerr.pkl')
# Out:
# ['scalerr.pkl']

# %%
df = df.rename(columns={'reading score': 'reading_score'})
df = df.rename(columns={'race/ethnicity_group B': 'race_ethnicity_group_B'})
df = df.rename(columns={'race/ethnicity_group C': 'race_ethnicity_group_C'})
df = df.rename(columns={'race/ethnicity_group D': 'race_ethnicity_group_D'})
df = df.rename(columns={'race/ethnicity_group E': 'race_ethnicity_group_E'})
df = df.rename(columns={"parental level of education_bachelor's degree": "parental_level_of_education_bachelor's_degree"})
df = df.rename(columns={'parental level of education_high school': 'parental_level_of_education_high_school'})
df = df.rename(columns={"parental level of education_master's degree": "parental_level_of_education_master's_degree"})
df = df.rename(columns={'parental level of education_some college': 'level_of_education_some_college'})
df = df.rename(columns={'parental level of education_some high school': 'parental_level_of_education_some_high_school'})
df = df.rename(columns={'test preparation course_none': 'test_preparation_course_none'})

# %%
df.columns
# Out:
# Index(['math score', 'reading_score', 'writing_score', 'gender_male',
#        'race_ethnicity_group_B', 'race_ethnicity_group_C',
#        'race_ethnicity_group_D', 'race_ethnicity_group_E',
#        'parental_level_of_education_bachelor's_degree',
#        'parental_level_of_education_high_school',
#        'parental_level_of_education_master's_degree',
#        'level_of_education_some_college',
#        'parental_level_of_education_some_high_school', 'lunch_standard',
#        'test_preparation_course_none'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   math score                                     1000 non-null   int64
#  1   reading_score                                  1000 non-null   int64
#  2   writing_score                                  1000 non-null   int64
#  3   gender_male                                    1000 non-null   int64
#  4   race_ethnicity_group_B                         1000 non-null   int64
#  5   race_ethnicity_group_C                         1000 non-null   int64
#  6   race_ethnicity_group_D                         1000 non-null   int64
#  7   race_ethnicity_group_E                         1000 non-null   int64
#  8   parental_level_of_education_bachelor's_degree  1000 non-null   int64
# ...

# %%
df
# Out:
#      math score  reading_score  writing_score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race_ethnicity_group_B  race_ethnicity_group_C  race_ethnicity_group_D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...
