# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39180 entries, 0 to 39179
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      39180 non-null  float64
#  1   person_gender                   39180 non-null  object
#  2   person_education                39180 non-null  object
#  3   person_income                   39180 non-null  float64
#  4   person_emp_exp                  39180 non-null  int64
#  5   person_home_ownership           39180 non-null  object
#  6   loan_amnt                       39180 non-null  float64
#  7   loan_intent                     39180 non-null  object
#  8   loan_int_rate                   39179 non-null  float64
#  9   loan_percent_income             39179 non-null  float64
#  10  cb_person_cred_hist_length      39179 non-null  float64
#  11  credit_score                    39179 non-null  float64
# ...

# %%
df.shape
# Out:
# (39180, 14)

# %%
df.select_dtypes(include='object').nunique()
# Out:
# person_gender                     2
# person_education                  5
# person_home_ownership             4
# loan_intent                       6
# previous_loan_defaults_on_file    2
# dtype: int64

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 39175        27.0          male      High School       100027.0
# 39176        32.0        female        Associate        74625.0
# 39177        33.0        female      High School        49382.0
# 39178        25.0        female           Master        46952.0
# 39179        29.0        female         Bachelor       120934.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
new_df = df[['person_age', 'person_income', 'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_int_rate','credit_score', 'loan_status']]

# %%
new_df.to_csv('loan_clear.csv')

# %%
df[['person_income', 'person_age','person_emp_exp',]].mean().round()
# Out:
# person_income     81317.0
# person_age           28.0
# person_emp_exp        5.0
# dtype: float64

# %%
(df['credit_score'] < 600).sum()
# Out:
# np.int64(9380)

# %%
df['person_home_ownership'].value_counts(normalize=True).round(3)
# Out:
# person_home_ownership
# RENT        0.501
# MORTGAGE    0.424
# OWN         0.072
# OTHER       0.003
# Name: proportion, dtype: float64

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 39175        27.0          male      High School       100027.0
# 39176        32.0        female        Associate        74625.0
# 39177        33.0        female      High School        49382.0
# 39178        25.0        female           Master        46952.0
# 39179        29.0        female         Bachelor       120934.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.groupby('loan_status')[['loan_int_rate', 'loan_amnt']].mean().round(2)
# Out:
#              loan_int_rate  loan_amnt
# loan_status
# 0.0                  10.48    9217.33
# 1.0                  12.87   10850.50

# %%
(df['person_emp_exp'] == 0).sum()
# Out:
# np.int64(8473)

# %%
(df['loan_percent_income'] > 0.5).sum()
# Out:
# np.int64(44)

# %%
df.groupby('person_home_ownership')['loan_int_rate'].mean().round()
# Out:
# person_home_ownership
# MORTGAGE    10.0
# OTHER       12.0
# OWN         11.0
# RENT        11.0
# Name: loan_int_rate, dtype: float64

# %%
sns.histplot(data=df, x='person_income', bins=120)
plt.xlabel('person_income')
plt.ylabel('количество')
plt.show()

# %%
sns.histplot(data=df, x='credit_score', bins=50, kde=True)
plt.xlabel('credit_score')
plt.ylabel('количество')
plt.show()

# %%
sns.histplot(data=df, x='loan_int_rate', bins=25, kde=True)
plt.xlabel('loan_int_rate')
plt.ylabel('количество')
plt.show()

# %%
sns.boxplot(data=df, x='loan_status', y='person_income', color='red')
plt.show()

# %%
sns.barplot(data=df, x='person_home_ownership', y='loan_status')
# Out:
# <Axes: xlabel='person_home_ownership', ylabel='loan_status'>

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 39175        27.0          male      High School       100027.0
# 39176        32.0        female        Associate        74625.0
# 39177        33.0        female      High School        49382.0
# 39178        25.0        female           Master        46952.0
# 39179        29.0        female         Bachelor       120934.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
new_df = df[['loan_status','credit_score', 'cb_person_cred_hist_length', 'loan_int_rate', 'loan_percent_income', 'loan_amnt', 'person_emp_exp', 'person_income', 'person_age']]
corr=new_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(new_df, corner=True, diag_kind='hist')

# %%
df2 = pd.read_csv('loan_clear.csv')

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0               0
# person_age               0
# person_income            0
# person_emp_exp           0
# person_home_ownership    0
# loan_amnt                0
# loan_int_rate            1
# credit_score             1
# loan_status              1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     1
# loan_percent_income               1
# cb_person_cred_hist_length        1
# credit_score                      1
# previous_loan_defaults_on_file    1
# loan_status                       1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# person_age                            0
# person_income                         0
# person_emp_exp                        0
# loan_amnt                             0
# loan_int_rate                         0
# loan_percent_income                   0
# cb_person_cred_hist_length            0
# credit_score                          0
# loan_status                           0
# person_gender_male                    0
# person_education_Bachelor             0
# person_education_Doctorate            0
# person_education_High School          0
# person_education_Master               0
# person_home_ownership_OTHER           0
# person_home_ownership_OWN             0
# person_home_ownership_RENT            0
# loan_intent_EDUCATION                 0
# loan_intent_HOMEIMPROVEMENT           0
# loan_intent_MEDICAL                   0
# loan_intent_PERSONAL                  0
# loan_intent_VENTURE                   0
# previous_loan_defaults_on_file_Yes    0
# dtype: int64

# %%
df['loan_int_rate'].fillna(df['loan_int_rate'].median(), inplace=True)
# Out:
# /tmp/ipython-input-364895585.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['loan_int_rate'].fillna(df['loan_int_rate'].median(), inplace=True)

# %%
df['loan_percent_income'].fillna(df['loan_percent_income'].median(), inplace=True)
# Out:
# /tmp/ipython-input-3196248460.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['loan_percent_income'].fillna(df['loan_percent_income'].median(), inplace=True)

# %%
df['cb_person_cred_hist_length'].fillna(df['cb_person_cred_hist_length'].median(), inplace=True)
# Out:
# /tmp/ipython-input-3904435413.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cb_person_cred_hist_length'].fillna(df['cb_person_cred_hist_length'].median(), inplace=True)

# %%
df['credit_score'].fillna(df['credit_score'].median(), inplace=True)
# Out:
# /tmp/ipython-input-1758788495.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['credit_score'].fillna(df['credit_score'].median(), inplace=True)

# %%
df['previous_loan_defaults_on_file'].fillna(df['previous_loan_defaults_on_file'].mode()[0], inplace=True)

# %%
df['loan_status'].fillna(df['loan_status'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3281443712.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['loan_status'].fillna(df['loan_status'].mode()[0], inplace=True)

# %%
df = pd.get_dummies(df, columns=['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file'], drop_first=True).astype(int)

# %%
df
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0              22          71948               0      35000             16
# 1              21          12282               0       1000             11
# 2              25          12438               3       5500             12
# 3              23          79753               0      35000             15
# 4              24          66135               1      35000             14
# ...           ...            ...             ...        ...            ...
# 39175          27         100027               2       5000              8
# 39176          32          74625              12      15000              7
# 39177          33          49382               7      16208              7
# 39178          25          46952               6      15156             14
# 39179          29         120934              10      20016             11
#
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0               0
# person_age               0
# person_income            0
# person_emp_exp           0
# person_home_ownership    0
# loan_amnt                0
# loan_int_rate            1
# credit_score             1
# loan_status              1
# dtype: int64

# %%
df2['loan_int_rate'].fillna(df2['loan_int_rate'].median(), inplace=True)
# Out:
# /tmp/ipython-input-2058814343.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['loan_int_rate'].fillna(df2['loan_int_rate'].median(), inplace=True)

# %%
df2['credit_score'].fillna(df2['credit_score'].median(), inplace=True)
# Out:
# /tmp/ipython-input-546020893.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['credit_score'].fillna(df2['credit_score'].median(), inplace=True)

# %%
df2['loan_status'].fillna(df2['loan_status'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3759083156.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['loan_status'].fillna(df2['loan_status'].mode()[0], inplace=True)

# %%
df2 = pd.get_dummies(df2, columns=['person_home_ownership'], drop_first=True).astype(int)

# %%
df2
# Out:
#        Unnamed: 0  person_age  person_income  person_emp_exp  loan_amnt  \
# 0               0          22          71948               0      35000
# 1               1          21          12282               0       1000
# 2               2          25          12438               3       5500
# 3               3          23          79753               0      35000
# 4               4          24          66135               1      35000
# ...           ...         ...            ...             ...        ...
# 39175       39175          27         100027               2       5000
# 39176       39176          32          74625              12      15000
# 39177       39177          33          49382               7      16208
# 39178       39178          25          46952               6      15156
# 39179       39179          29         120934              10      20016
#
#        loan_int_rate  credit_score  loan_status  person_home_ownership_OTHER  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = df.drop(columns=('loan_status'))
scaled_data = scaler.fit_transform(features)

# %%
from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()
feautres2 = df2.drop(columns=('loan_status'))
scaled_data2 = scaler.fit_transform(features)

# %%
x = scaled_data
y = df['loan_status']

# %%
r = scaled_data2
t = df2['loan_status']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
r_train, r_test, t_train, t_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model2 = LogisticRegression()

# %%
log_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
log_model2.fit(r_train, t_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_model.predict(x_test)

# %%
y_pred2 = log_model2.predict(r_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.892802450229709

# %%
from sklearn.metrics import accuracy_score
accuracy_score(t_test, y_pred2)
# Out:
# 0.892802450229709

# %%
import joblib
joblib.dump(log_model, 'model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
joblib.dump(log_model2, 'model2.pkl')
joblib.dump(scaler2, 'scaler2.pkl')
# Out:
# ['scaler2.pkl']
